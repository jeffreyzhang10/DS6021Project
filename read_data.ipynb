# %%
import pandas as pd

# %%
def read_data(df, wk):
    file = df + "_2023_w" + str(wk) + ".csv"
    data = pd.read_csv(file)
    return data

# %%
input_data = pd.DataFrame()
output_data = pd.DataFrame()
s_data = pd.read_csv("supplementary_data.csv")
for wk in range(1, 19):
    wk_str = '{:02d}'.format(wk)
    input_df = read_data('input', wk_str)
    output_df = read_data('output', wk_str)
    input_df['wk'] = wk
    output_df['wk'] = wk
    input_data = pd.concat([input_data, input_df], ignore_index=True)
    output_data = pd.concat([output_data, output_df], ignore_index=True)
# Out:
# /var/folders/js/d_qzf0bs4v1gw_dwxd4bhx7h0000gp/T/ipykernel_20010/3745984903.py:3: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   s_data = pd.read_csv("supplementary_data.csv")

# %%
input_data
# Out:
#             game_id  play_id  player_to_predict  nfl_id  frame_id  \
# 0        2023090700      101              False   54527         1
# 1        2023090700      101              False   54527         2
# 2        2023090700      101              False   54527         3
# 3        2023090700      101              False   54527         4
# 4        2023090700      101              False   54527         5
# ...             ...      ...                ...     ...       ...
# 4880574  2024010713     4018               True   52457        23
# 4880575  2024010713     4018               True   52457        24
# 4880576  2024010713     4018               True   52457        25
# 4880577  2024010713     4018               True   52457        26
# 4880578  2024010713     4018               True   52457        27
#
#         play_direction  absolute_yardline_number     player_name  \
# 0                right                        42      Bryan Cook
# ...
